# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from config import weather_api_key
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(-90.000, 90.000, size=2000)
lngs = np.random.uniform(-180.000, 180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
     # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 731

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather['weather'][0]['description']
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description})
        
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")

# city_weather = requests.get(city_url).json()
# city_weather
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | jiuquan
# Processing Record 2 of Set 1 | tuktoyaktuk
# Processing Record 3 of Set 1 | killybegs
# Processing Record 4 of Set 1 | thompson
# Processing Record 5 of Set 1 | kaitangata
# Processing Record 6 of Set 1 | san patricio
# Processing Record 7 of Set 1 | georgetown
# Processing Record 8 of Set 1 | saldanha
# Processing Record 9 of Set 1 | torbay
# Processing Record 10 of Set 1 | cherskiy
# Processing Record 11 of Set 1 | butaritari
# Processing Record 12 of Set 1 | caravelas
# Processing Record 13 of Set 1 | hobart
# Processing Record 14 of Set 1 | new norfolk
# Processing Record 15 of Set 1 | nome
# Processing Record 16 of Set 1 | vaini
# Processing Record 17 of Set 1 | atuona
# Processing Record 18 of Set 1 | saint-philippe
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 21 of Set 1 | yellowknife
# Processing Record 22 of Set 1 | punta arenas
# Processing Record 23 of Set 1 | khasan
# Processing Record 24 of Set 1 | huarmey
# Processing Record 25 of Set 1 | salvador
# Processing Record 26 of Set 1 | alofi
# Processing Record 27 of Set 1 | mataura
# Processing Record 28 of Set 1 | bredasdorp
# Processing Record 29 of Set 1 | nuuk
# Processing Record 30 of Set 1 | tasiilaq
# Processing Record 31 of Set 1 | nhulunbuy
# Processing Record 32 of Set 1 | hilo
# Processing Record 33 of Set 1 | clyde river
# Processing Record 34 of Set 1 | vostok
# Processing Record 35 of Set 1 | port hedland
# Processing Record 36 of Set 1 | bambous virieux
# Processing Record 37 of Set 1 | barrow
# Processing Record 38 of Set 1 | luderitz
# Processing Record 39 of Set 1 | waipawa
# Processing Record 40 of Set 1 | ostersund
# Processing Record 41 of Set 1 | saint-augustin
# Processing Record 42 of Set 1 | muyezerskiy
# Processing Record 43 of Set 1 | fairbanks
# Processing Record 44 of Set 1 | chippewa falls
# Processing Record 45 of Set 1 | ushuaia
# Processing Record 46 of Set 1 | havoysund
# Processing Record 47 of Set 1 | teguise
# Processing Record 48 of Set 1 | lagoa
# Processing Record 49 of Set 1 | kalmunai
# Processing Record 50 of Set 1 | nikolskoye
# Processing Record 1 of Set 2 | hermanus
# Processing Record 2 of Set 2 | avarua
# Processing Record 3 of Set 2 | sambava
# Processing Record 4 of Set 2 | faanui
# Processing Record 5 of Set 2 | bluff
# Processing Record 6 of Set 2 | upernavik
# Processing Record 7 of Set 2 | jalaun
# Processing Record 8 of Set 2 | lhokseumawe
# Processing Record 9 of Set 2 | chagda
# City not found. Skipping...
# Processing Record 10 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 11 of Set 2 | leningradskiy
# Processing Record 12 of Set 2 | hualmay
# Processing Record 13 of Set 2 | fukue
# Processing Record 14 of Set 2 | faya
# Processing Record 15 of Set 2 | soledade
# Processing Record 16 of Set 2 | nsoko
# Processing Record 17 of Set 2 | kodiak
# Processing Record 18 of Set 2 | ribeira grande
# Processing Record 19 of Set 2 | belyy yar
# Processing Record 20 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 21 of Set 2 | trofors
# Processing Record 22 of Set 2 | hailey
# Processing Record 23 of Set 2 | opuwo
# Processing Record 24 of Set 2 | fortuna
# Processing Record 25 of Set 2 | pevek
# Processing Record 26 of Set 2 | nizhniy kuranakh
# Processing Record 27 of Set 2 | eydhafushi
# Processing Record 28 of Set 2 | sabha
# Processing Record 29 of Set 2 | pastavy
# Processing Record 30 of Set 2 | rolim de moura
# City not found. Skipping...
# Processing Record 31 of Set 2 | puerto ayora
# Processing Record 32 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 33 of Set 2 | laguna
# Processing Record 34 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 35 of Set 2 | albany
# Processing Record 36 of Set 2 | solovetskiy
# City not found. Skipping...
# Processing Record 37 of Set 2 | tessalit
# Processing Record 38 of Set 2 | kangalassy
# Processing Record 39 of Set 2 | adrar
# Processing Record 40 of Set 2 | nantucket
# Processing Record 41 of Set 2 | busselton
# Processing Record 42 of Set 2 | qasigiannguit
# Processing Record 43 of Set 2 | maumere
# Processing Record 44 of Set 2 | aklavik
# Processing Record 45 of Set 2 | amapa
# Processing Record 46 of Set 2 | broome
# Processing Record 47 of Set 2 | temaraia
# City not found. Skipping...
# Processing Record 48 of Set 2 | kavaratti
# Processing Record 49 of Set 2 | fairmont
# Processing Record 50 of Set 2 | cape town
# Processing Record 1 of Set 3 | jacareacanga
# Processing Record 2 of Set 3 | rincon
# Processing Record 3 of Set 3 | adjumani
# Processing Record 4 of Set 3 | maxixe
# Processing Record 5 of Set 3 | pemagatsel
# Processing Record 6 of Set 3 | surt
# Processing Record 7 of Set 3 | marawi
# Processing Record 8 of Set 3 | gharb
# City not found. Skipping...
# Processing Record 9 of Set 3 | okhotsk
# Processing Record 10 of Set 3 | yar-sale
# Processing Record 11 of Set 3 | sinnamary
# Processing Record 12 of Set 3 | susurluk
# Processing Record 13 of Set 3 | amasia
# Processing Record 14 of Set 3 | cidreira
# Processing Record 15 of Set 3 | lata
# Processing Record 16 of Set 3 | lavrentiya
# Processing Record 17 of Set 3 | nogliki
# Processing Record 18 of Set 3 | witbank
# Processing Record 19 of Set 3 | jamestown
# Processing Record 20 of Set 3 | carnarvon
# Processing Record 21 of Set 3 | katsuura
# Processing Record 22 of Set 3 | castro
# Processing Record 23 of Set 3 | barabinsk
# Processing Record 24 of Set 3 | mullaitivu
# City not found. Skipping...
# Processing Record 25 of Set 3 | port blair
# Processing Record 26 of Set 3 | erenhot
# Processing Record 27 of Set 3 | zabid
# Processing Record 28 of Set 3 | asyut
# Processing Record 29 of Set 3 | la ronge
# Processing Record 30 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 31 of Set 3 | klaksvik
# Processing Record 32 of Set 3 | padang
# Processing Record 33 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 34 of Set 3 | ilulissat
# Processing Record 35 of Set 3 | walvis bay
# Processing Record 36 of Set 3 | dali
# Processing Record 37 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 38 of Set 3 | aswan
# Processing Record 39 of Set 3 | arraial do cabo
# Processing Record 40 of Set 3 | karamea
# City not found. Skipping...
# Processing Record 41 of Set 3 | tiznit
# Processing Record 42 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 43 of Set 3 | hithadhoo
# Processing Record 44 of Set 3 | verkhnetulomskiy
# Processing Record 45 of Set 3 | sardinata
# Processing Record 46 of Set 3 | aksu
# Processing Record 47 of Set 3 | san policarpo
# Processing Record 48 of Set 3 | east london
# Processing Record 49 of Set 3 | chake chake
# Processing Record 50 of Set 3 | progreso
# Processing Record 1 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 2 of Set 4 | labuhan
# Processing Record 3 of Set 4 | khatanga
# Processing Record 4 of Set 4 | longyearbyen
# Processing Record 5 of Set 4 | jiroft
# City not found. Skipping...
# Processing Record 6 of Set 4 | baiyin
# Processing Record 7 of Set 4 | darnah
# Processing Record 8 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 4 | agadez
# Processing Record 10 of Set 4 | chernyanka
# Processing Record 11 of Set 4 | mahebourg
# Processing Record 12 of Set 4 | guane
# Processing Record 13 of Set 4 | adre
# Processing Record 14 of Set 4 | irbit
# Processing Record 15 of Set 4 | port alfred
# Processing Record 16 of Set 4 | porosozero
# Processing Record 17 of Set 4 | buta
# Processing Record 18 of Set 4 | san juan del sur
# Processing Record 19 of Set 4 | shirokiy
# Processing Record 20 of Set 4 | codrington
# Processing Record 21 of Set 4 | kapaa
# Processing Record 22 of Set 4 | lorengau
# Processing Record 23 of Set 4 | rocha
# Processing Record 24 of Set 4 | sao filipe
# Processing Record 25 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 4 | peleduy
# Processing Record 27 of Set 4 | tuatapere
# Processing Record 28 of Set 4 | tiksi
# Processing Record 29 of Set 4 | harper
# Processing Record 30 of Set 4 | terrace
# Processing Record 31 of Set 4 | amuntai
# Processing Record 32 of Set 4 | jefferson city
# Processing Record 33 of Set 4 | cabo san lucas
# Processing Record 34 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 35 of Set 4 | vanimo
# Processing Record 36 of Set 4 | pangoa
# Processing Record 37 of Set 4 | jumla
# Processing Record 38 of Set 4 | honiara
# Processing Record 39 of Set 4 | soyo
# Processing Record 40 of Set 4 | vao
# Processing Record 41 of Set 4 | fort saint john
# City not found. Skipping...
# Processing Record 42 of Set 4 | gao
# Processing Record 43 of Set 4 | qaqortoq
# Processing Record 44 of Set 4 | innisfail
# Processing Record 45 of Set 4 | ekibastuz
# Processing Record 46 of Set 4 | chuy
# Processing Record 47 of Set 4 | victoria
# Processing Record 48 of Set 4 | saint george
# Processing Record 49 of Set 4 | kasongo-lunda
# Processing Record 50 of Set 4 | kinshasa
# Processing Record 1 of Set 5 | izhma
# Processing Record 2 of Set 5 | provideniya
# Processing Record 3 of Set 5 | almaznyy
# Processing Record 4 of Set 5 | eureka
# Processing Record 5 of Set 5 | portland
# Processing Record 6 of Set 5 | kruisfontein
# Processing Record 7 of Set 5 | denia
# Processing Record 8 of Set 5 | korla
# Processing Record 9 of Set 5 | champerico
# Processing Record 10 of Set 5 | babanusah
# City not found. Skipping...
# Processing Record 11 of Set 5 | itoman
# Processing Record 12 of Set 5 | waingapu
# Processing Record 13 of Set 5 | chupa
# Processing Record 14 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 15 of Set 5 | port-gentil
# Processing Record 16 of Set 5 | pandan
# Processing Record 17 of Set 5 | trat
# Processing Record 18 of Set 5 | vila velha
# Processing Record 19 of Set 5 | tirupati
# Processing Record 20 of Set 5 | sibu
# Processing Record 21 of Set 5 | dubai
# Processing Record 22 of Set 5 | lompoc
# Processing Record 23 of Set 5 | nurota
# Processing Record 24 of Set 5 | geraldton
# Processing Record 25 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 26 of Set 5 | rudraprayag
# Processing Record 27 of Set 5 | shache
# Processing Record 28 of Set 5 | esperance
# Processing Record 29 of Set 5 | plouzane
# Processing Record 30 of Set 5 | libourne
# Processing Record 31 of Set 5 | ahipara
# Processing Record 32 of Set 5 | inhambane
# Processing Record 33 of Set 5 | bethel
# Processing Record 34 of Set 5 | takhatgarh
# Processing Record 35 of Set 5 | port elizabeth
# Processing Record 36 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 37 of Set 5 | cockburn town
# Processing Record 38 of Set 5 | sawakin
# Processing Record 39 of Set 5 | tigil
# Processing Record 40 of Set 5 | aloleng
# Processing Record 41 of Set 5 | garissa
# Processing Record 42 of Set 5 | svetlaya
# Processing Record 43 of Set 5 | alegrete
# Processing Record 44 of Set 5 | kidal
# Processing Record 45 of Set 5 | krasnoselkup
# Processing Record 46 of Set 5 | shimoda
# Processing Record 47 of Set 5 | marondera
# Processing Record 48 of Set 5 | nuevitas
# Processing Record 49 of Set 5 | mehriz
# Processing Record 50 of Set 5 | san vicente
# Processing Record 1 of Set 6 | kirgiz-miyaki
# Processing Record 2 of Set 6 | whitehorse
# Processing Record 3 of Set 6 | madimba
# Processing Record 4 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 6 | talnakh
# Processing Record 6 of Set 6 | ponta do sol
# Processing Record 7 of Set 6 | uwajima
# Processing Record 8 of Set 6 | mar del plata
# Processing Record 9 of Set 6 | zhigansk
# Processing Record 10 of Set 6 | ji-parana
# City not found. Skipping...
# Processing Record 11 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 12 of Set 6 | morant bay
# Processing Record 13 of Set 6 | asfi
# Processing Record 14 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 15 of Set 6 | ust-ilimsk
# Processing Record 16 of Set 6 | touros
# Processing Record 17 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 18 of Set 6 | mitchell
# Processing Record 19 of Set 6 | anadyr
# Processing Record 20 of Set 6 | olga
# Processing Record 21 of Set 6 | rathdrum
# Processing Record 22 of Set 6 | marzuq
# Processing Record 23 of Set 6 | hofn
# Processing Record 24 of Set 6 | tabou
# Processing Record 25 of Set 6 | baturyn
# Processing Record 26 of Set 6 | airai
# Processing Record 27 of Set 6 | college
# Processing Record 28 of Set 6 | puerto maldonado
# Processing Record 29 of Set 6 | qaanaaq
# Processing Record 30 of Set 6 | thinadhoo
# Processing Record 31 of Set 6 | south sioux city
# Processing Record 32 of Set 6 | mount isa
# Processing Record 33 of Set 6 | brae
# Processing Record 34 of Set 6 | espanola
# Processing Record 35 of Set 6 | berlevag
# Processing Record 36 of Set 6 | lebu
# Processing Record 37 of Set 6 | rognan
# Processing Record 38 of Set 6 | hanzhong
# Processing Record 39 of Set 6 | jurm
# Processing Record 40 of Set 6 | rawannawi
# City not found. Skipping...
# Processing Record 41 of Set 6 | miraflores
# Processing Record 42 of Set 6 | jalu
# Processing Record 43 of Set 6 | ust-nera
# Processing Record 44 of Set 6 | kibala
# Processing Record 45 of Set 6 | kribi
# Processing Record 46 of Set 6 | mazsalaca
# Processing Record 47 of Set 6 | avera
# Processing Record 48 of Set 6 | isla vista
# Processing Record 49 of Set 6 | namatanai
# Processing Record 50 of Set 6 | piacabucu
# Processing Record 1 of Set 7 | lazaro cardenas
# Processing Record 2 of Set 7 | vokhma
# Processing Record 3 of Set 7 | kisangani
# Processing Record 4 of Set 7 | bacuit
# City not found. Skipping...
# Processing Record 5 of Set 7 | kurilsk
# Processing Record 6 of Set 7 | puerto padre
# Processing Record 7 of Set 7 | diego de almagro
# Processing Record 8 of Set 7 | sao joao da barra
# Processing Record 9 of Set 7 | neuquen
# Processing Record 10 of Set 7 | staryy nadym
# Processing Record 11 of Set 7 | scottsburgh
# City not found. Skipping...
# Processing Record 12 of Set 7 | atasu
# Processing Record 13 of Set 7 | samarai
# Processing Record 14 of Set 7 | oktyabrskiy
# Processing Record 15 of Set 7 | dikson
# Processing Record 16 of Set 7 | manado
# Processing Record 17 of Set 7 | kamenka
# Processing Record 18 of Set 7 | paamiut
# Processing Record 19 of Set 7 | axim
# Processing Record 20 of Set 7 | angoche
# Processing Record 21 of Set 7 | chapleau
# Processing Record 22 of Set 7 | awjilah
# Processing Record 23 of Set 7 | yeppoon
# Processing Record 24 of Set 7 | asau
# Processing Record 25 of Set 7 | ca mau
# Processing Record 26 of Set 7 | uray
# Processing Record 27 of Set 7 | nemuro
# Processing Record 28 of Set 7 | tanete
# Processing Record 29 of Set 7 | tautira
# Processing Record 30 of Set 7 | palmer
# Processing Record 31 of Set 7 | sitka
# Processing Record 32 of Set 7 | kerrobert
# Processing Record 33 of Set 7 | talas
# Processing Record 34 of Set 7 | kyra
# Processing Record 35 of Set 7 | port shepstone
# Processing Record 36 of Set 7 | norman wells
# Processing Record 37 of Set 7 | keetmanshoop
# Processing Record 38 of Set 7 | north bend
# Processing Record 39 of Set 7 | kemijarvi
# Processing Record 40 of Set 7 | poum
# Processing Record 41 of Set 7 | itaituba
# Processing Record 42 of Set 7 | paradwip
# City not found. Skipping...
# Processing Record 43 of Set 7 | karangampel
# Processing Record 44 of Set 7 | pisco
# Processing Record 45 of Set 7 | hay river
# Processing Record 46 of Set 7 | kati
# Processing Record 47 of Set 7 | trincomalee
# Processing Record 48 of Set 7 | tartagal
# Processing Record 49 of Set 7 | yarada
# Processing Record 50 of Set 7 | deh rawud
# City not found. Skipping...
# Processing Record 1 of Set 8 | jibuti
# Processing Record 2 of Set 8 | san cristobal
# Processing Record 3 of Set 8 | fare
# Processing Record 4 of Set 8 | ranong
# Processing Record 5 of Set 8 | romny
# Processing Record 6 of Set 8 | chokurdakh
# Processing Record 7 of Set 8 | merauke
# Processing Record 8 of Set 8 | northam
# Processing Record 9 of Set 8 | zelenogradsk
# Processing Record 10 of Set 8 | wamba
# Processing Record 11 of Set 8 | hambantota
# Processing Record 12 of Set 8 | atambua
# Processing Record 13 of Set 8 | bemidji
# Processing Record 14 of Set 8 | havre-saint-pierre
# Processing Record 15 of Set 8 | souillac
# Processing Record 16 of Set 8 | kavieng
# Processing Record 17 of Set 8 | banda aceh
# Processing Record 18 of Set 8 | graaff-reinet
# Processing Record 19 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 20 of Set 8 | bowen
# Processing Record 21 of Set 8 | hasaki
# Processing Record 22 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 23 of Set 8 | labuan
# Processing Record 24 of Set 8 | yulara
# Processing Record 25 of Set 8 | el banco
# Processing Record 26 of Set 8 | kalianget
# Processing Record 27 of Set 8 | sur
# Processing Record 28 of Set 8 | si sa ket
# Processing Record 29 of Set 8 | iskateley
# Processing Record 30 of Set 8 | jinka
# Processing Record 31 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 32 of Set 8 | santiago del estero
# Processing Record 33 of Set 8 | grand centre
# City not found. Skipping...
# Processing Record 34 of Set 8 | parabel
# Processing Record 35 of Set 8 | los llanos de aridane
# Processing Record 36 of Set 8 | ahuimanu
# Processing Record 37 of Set 8 | taltal
# Processing Record 38 of Set 8 | talara
# Processing Record 39 of Set 8 | ambon
# Processing Record 40 of Set 8 | sri aman
# Processing Record 41 of Set 8 | dudinka
# Processing Record 42 of Set 8 | suba
# Processing Record 43 of Set 8 | ulaangom
# Processing Record 44 of Set 8 | chabahar
# Processing Record 45 of Set 8 | opobo
# City not found. Skipping...
# Processing Record 46 of Set 8 | menongue
# Processing Record 47 of Set 8 | thaton
# Processing Record 48 of Set 8 | jabinyanah
# Processing Record 49 of Set 8 | celestun
# Processing Record 50 of Set 8 | maputo
# Processing Record 1 of Set 9 | santa cruz
# Processing Record 2 of Set 9 | bilma
# Processing Record 3 of Set 9 | hobbs
# Processing Record 4 of Set 9 | dasoguz
# Processing Record 5 of Set 9 | isangel
# Processing Record 6 of Set 9 | ucluelet
# Processing Record 7 of Set 9 | calabozo
# Processing Record 8 of Set 9 | manggar
# Processing Record 9 of Set 9 | muros
# Processing Record 10 of Set 9 | shenjiamen
# Processing Record 11 of Set 9 | nanortalik
# Processing Record 12 of Set 9 | kamwenge
# Processing Record 13 of Set 9 | corsicana
# Processing Record 14 of Set 9 | chingirlau
# Processing Record 15 of Set 9 | vardo
# Processing Record 16 of Set 9 | ettaiyapuram
# Processing Record 17 of Set 9 | trelew
# Processing Record 18 of Set 9 | lamu
# Processing Record 19 of Set 9 | christchurch
# Processing Record 20 of Set 9 | grand gaube
# Processing Record 21 of Set 9 | kempele
# Processing Record 22 of Set 9 | haines junction
# Processing Record 23 of Set 9 | khonuu
# City not found. Skipping...
# Processing Record 24 of Set 9 | gemena
# Processing Record 25 of Set 9 | sakakah
# Processing Record 26 of Set 9 | asosa
# Processing Record 27 of Set 9 | iqaluit
# Processing Record 28 of Set 9 | olavarria
# Processing Record 29 of Set 9 | saskylakh
# Processing Record 30 of Set 9 | kununurra
# Processing Record 31 of Set 9 | panalingaan
# Processing Record 32 of Set 9 | ati
# Processing Record 33 of Set 9 | mogadishu
# Processing Record 34 of Set 9 | sola
# Processing Record 35 of Set 9 | atar
# Processing Record 36 of Set 9 | voh
# Processing Record 37 of Set 9 | goderich
# Processing Record 38 of Set 9 | norrkoping
# Processing Record 39 of Set 9 | valle de allende
# Processing Record 40 of Set 9 | cabedelo
# Processing Record 41 of Set 9 | tabory
# Processing Record 42 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 43 of Set 9 | collie
# Processing Record 44 of Set 9 | prince rupert
# Processing Record 45 of Set 9 | baykit
# Processing Record 46 of Set 9 | ugoofaaru
# Processing Record 47 of Set 9 | estelle
# Processing Record 48 of Set 9 | yanam
# Processing Record 49 of Set 9 | namie
# Processing Record 50 of Set 9 | lingao
# Processing Record 1 of Set 10 | antalaha
# Processing Record 2 of Set 10 | bitung
# Processing Record 3 of Set 10 | maragogi
# Processing Record 4 of Set 10 | namibe
# Processing Record 5 of Set 10 | shingu
# Processing Record 6 of Set 10 | arklow
# Processing Record 7 of Set 10 | bara
# Processing Record 8 of Set 10 | boende
# Processing Record 9 of Set 10 | chardara
# Processing Record 10 of Set 10 | tommot
# Processing Record 11 of Set 10 | spring hill
# Processing Record 12 of Set 10 | thunder bay
# Processing Record 13 of Set 10 | lashio
# Processing Record 14 of Set 10 | kloulklubed
# Processing Record 15 of Set 10 | bandar
# Processing Record 16 of Set 10 | san jose
# Processing Record 17 of Set 10 | armeria
# Processing Record 18 of Set 10 | winnemucca
# Processing Record 19 of Set 10 | ippy
# Processing Record 20 of Set 10 | jasper
# Processing Record 21 of Set 10 | itarema
# Processing Record 22 of Set 10 | bonanza
# Processing Record 23 of Set 10 | kinkala
# Processing Record 24 of Set 10 | naze
# Processing Record 25 of Set 10 | bud
# Processing Record 26 of Set 10 | diamantino
# Processing Record 27 of Set 10 | biella
# Processing Record 28 of Set 10 | liaozhong
# Processing Record 29 of Set 10 | oskarshamn
# Processing Record 30 of Set 10 | rongcheng
# Processing Record 31 of Set 10 | thayetmyo
# Processing Record 32 of Set 10 | shancheng
# Processing Record 33 of Set 10 | iraga
# Processing Record 34 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 35 of Set 10 | taoudenni
# Processing Record 36 of Set 10 | dingle
# Processing Record 37 of Set 10 | zitlala
# Processing Record 38 of Set 10 | general pico
# Processing Record 39 of Set 10 | meulaboh
# Processing Record 40 of Set 10 | flin flon
# Processing Record 41 of Set 10 | bubaque
# Processing Record 42 of Set 10 | yumen
# Processing Record 43 of Set 10 | bababe
# City not found. Skipping...
# Processing Record 44 of Set 10 | yoichi
# Processing Record 45 of Set 10 | jurado
# Processing Record 46 of Set 10 | chicama
# Processing Record 47 of Set 10 | narsipatnam
# Processing Record 48 of Set 10 | husainabad
# Processing Record 49 of Set 10 | leh
# Processing Record 50 of Set 10 | alyangula
# Processing Record 1 of Set 11 | basco
# Processing Record 2 of Set 11 | constitucion
# Processing Record 3 of Set 11 | genteng
# Processing Record 4 of Set 11 | ostrovnoy
# Processing Record 5 of Set 11 | puerto cabello
# Processing Record 6 of Set 11 | bloemfontein
# Processing Record 7 of Set 11 | grand-santi
# Processing Record 8 of Set 11 | najran
# Processing Record 9 of Set 11 | chara
# Processing Record 10 of Set 11 | guadalupe victoria
# Processing Record 11 of Set 11 | nicoya
# Processing Record 12 of Set 11 | severo-kurilsk
# Processing Record 13 of Set 11 | cumaribo
# City not found. Skipping...
# Processing Record 14 of Set 11 | mnogovershinnyy
# Processing Record 15 of Set 11 | raudeberg
# Processing Record 16 of Set 11 | liverpool
# Processing Record 17 of Set 11 | satitoa
# City not found. Skipping...
# Processing Record 18 of Set 11 | elizabeth city
# Processing Record 19 of Set 11 | cerrito
# Processing Record 20 of Set 11 | promyshlennovskiy
# Processing Record 21 of Set 11 | chama
# Processing Record 22 of Set 11 | lithakia
# Processing Record 23 of Set 11 | liberal
# Processing Record 24 of Set 11 | vestmanna
# Processing Record 25 of Set 11 | komsomolskiy
# Processing Record 26 of Set 11 | banikoara
# Processing Record 27 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 28 of Set 11 | guiratinga
# Processing Record 29 of Set 11 | suhbaatar
# Processing Record 30 of Set 11 | evensk
# Processing Record 31 of Set 11 | westport
# Processing Record 32 of Set 11 | grand-lahou
# Processing Record 33 of Set 11 | ixtapa
# Processing Record 34 of Set 11 | griffith
# Processing Record 35 of Set 11 | horta
# Processing Record 36 of Set 11 | mao
# Processing Record 37 of Set 11 | cocal
# Processing Record 38 of Set 11 | narsaq
# Processing Record 39 of Set 11 | launceston
# Processing Record 40 of Set 11 | half moon bay
# Processing Record 41 of Set 11 | sorland
# Processing Record 42 of Set 11 | cedar city
# Processing Record 43 of Set 11 | chalmette
# Processing Record 44 of Set 11 | saint anthony
# Processing Record 45 of Set 11 | tura
# Processing Record 46 of Set 11 | salinas
# Processing Record 47 of Set 11 | mehamn
# Processing Record 48 of Set 11 | salta
# Processing Record 49 of Set 11 | forestville
# Processing Record 50 of Set 11 | bilibino
# Processing Record 1 of Set 12 | kroderen
# City not found. Skipping...
# Processing Record 2 of Set 12 | bloomingdale
# Processing Record 3 of Set 12 | erzin
# Processing Record 4 of Set 12 | valenca do piaui
# Processing Record 5 of Set 12 | bengkulu
# Processing Record 6 of Set 12 | comodoro rivadavia
# Processing Record 7 of Set 12 | sao felix do xingu
# Processing Record 8 of Set 12 | yanchukan
# City not found. Skipping...
# Processing Record 9 of Set 12 | abidjan
# Processing Record 10 of Set 12 | tiarei
# Processing Record 11 of Set 12 | palora
# Processing Record 12 of Set 12 | deep river
# Processing Record 13 of Set 12 | chapais
# Processing Record 14 of Set 12 | kalevala
# Processing Record 15 of Set 12 | hwange
# Processing Record 16 of Set 12 | pundaguitan
# Processing Record 17 of Set 12 | kerema
# Processing Record 18 of Set 12 | imeni poliny osipenko
# Processing Record 19 of Set 12 | macae
# Processing Record 20 of Set 12 | xai-xai
# Processing Record 21 of Set 12 | igrim
# Processing Record 22 of Set 12 | baruun-urt
# Processing Record 23 of Set 12 | auki
# Processing Record 24 of Set 12 | mayo
# Processing Record 25 of Set 12 | riyadh
# Processing Record 26 of Set 12 | chimbote
# Processing Record 27 of Set 12 | verkhnevilyuysk
# Processing Record 28 of Set 12 | carnot
# Processing Record 29 of Set 12 | takoradi
# Processing Record 30 of Set 12 | beringovskiy
# Processing Record 31 of Set 12 | azogues
# Processing Record 32 of Set 12 | rorvik
# Processing Record 33 of Set 12 | afmadu
# City not found. Skipping...
# Processing Record 34 of Set 12 | xuddur
# Processing Record 35 of Set 12 | pareora
# Processing Record 36 of Set 12 | bhuj
# Processing Record 37 of Set 12 | udachnyy
# Processing Record 38 of Set 12 | banjar
# Processing Record 39 of Set 12 | batticaloa
# Processing Record 40 of Set 12 | sirsa
# Processing Record 41 of Set 12 | gat
# Processing Record 42 of Set 12 | maykain
# City not found. Skipping...
# Processing Record 43 of Set 12 | oranjemund
# Processing Record 44 of Set 12 | santa lucia
# Processing Record 45 of Set 12 | novikovo
# Processing Record 46 of Set 12 | kihei
# Processing Record 47 of Set 12 | brigantine
# Processing Record 48 of Set 12 | puerto escondido
# Processing Record 49 of Set 12 | bayan
# Processing Record 50 of Set 12 | capaci
# Processing Record 1 of Set 13 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 13 | nishihara
# Processing Record 3 of Set 13 | teshie
# Processing Record 4 of Set 13 | reshetylivka
# Processing Record 5 of Set 13 | saint-francois
# Processing Record 6 of Set 13 | cabimas
# Processing Record 7 of Set 13 | matagami
# Processing Record 8 of Set 13 | tangzhai
# Processing Record 9 of Set 13 | pitsunda
# Processing Record 10 of Set 13 | la uribe
# City not found. Skipping...
# Processing Record 11 of Set 13 | semey
# Processing Record 12 of Set 13 | vysokogornyy
# Processing Record 13 of Set 13 | baikunthpur
# Processing Record 14 of Set 13 | hami
# Processing Record 15 of Set 13 | ingleside
# Processing Record 16 of Set 13 | hamilton
# Processing Record 17 of Set 13 | ancud
# Processing Record 18 of Set 13 | gornopravdinsk
# Processing Record 19 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 20 of Set 13 | sabinopolis
# Processing Record 21 of Set 13 | laizhou
# Processing Record 22 of Set 13 | kuryk
# Processing Record 23 of Set 13 | tocopilla
# Processing Record 24 of Set 13 | vestmannaeyjar
# Processing Record 25 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 26 of Set 13 | aljustrel
# Processing Record 27 of Set 13 | sedkyrkeshch
# Processing Record 28 of Set 13 | sharjah
# Processing Record 29 of Set 13 | xingcheng
# Processing Record 30 of Set 13 | corpus christi
# Processing Record 31 of Set 13 | kathua
# Processing Record 32 of Set 13 | mumford
# Processing Record 33 of Set 13 | alencon
# Processing Record 34 of Set 13 | hals
# Processing Record 35 of Set 13 | salalah
# Processing Record 36 of Set 13 | mananjary
# Processing Record 37 of Set 13 | melfort
# Processing Record 38 of Set 13 | bandarbeyla
# Processing Record 39 of Set 13 | dalvik
# Processing Record 40 of Set 13 | moses lake
# Processing Record 41 of Set 13 | buchanan
# Processing Record 42 of Set 13 | bantogon
# Processing Record 43 of Set 13 | altamira
# Processing Record 44 of Set 13 | birao
# Processing Record 45 of Set 13 | simao
# Processing Record 46 of Set 13 | bom jardim
# Processing Record 47 of Set 13 | kasama
# Processing Record 48 of Set 13 | port hardy
# Processing Record 49 of Set 13 | socorro
# Processing Record 50 of Set 13 | dingli
# Processing Record 1 of Set 14 | areka
# Processing Record 2 of Set 14 | port hawkesbury
# Processing Record 3 of Set 14 | synya
# Processing Record 4 of Set 14 | vila franca do campo
# Processing Record 5 of Set 14 | road town
# Processing Record 6 of Set 14 | sendafa
# Processing Record 7 of Set 14 | naranjal
# Processing Record 8 of Set 14 | charcas
# Processing Record 9 of Set 14 | sayyan
# Processing Record 10 of Set 14 | cholan
# City not found. Skipping...
# Processing Record 11 of Set 14 | gonbad-e qabus
# Processing Record 12 of Set 14 | pudozh
# Processing Record 13 of Set 14 | puerto madryn
# Processing Record 14 of Set 14 | egvekinot
# Processing Record 15 of Set 14 | asahikawa
# Processing Record 16 of Set 14 | nong khai
# Processing Record 17 of Set 14 | fraga
# Processing Record 18 of Set 14 | taitung
# Processing Record 19 of Set 14 | gunjur
# Processing Record 20 of Set 14 | bowmore
# Processing Record 21 of Set 14 | cairns
# Processing Record 22 of Set 14 | kanadey
# Processing Record 23 of Set 14 | hirara
# Processing Record 24 of Set 14 | lasa
# Processing Record 25 of Set 14 | port moresby
# Processing Record 26 of Set 14 | hovd
# Processing Record 27 of Set 14 | tagusao
# Processing Record 28 of Set 14 | sarangani
# Processing Record 29 of Set 14 | ayni
# Processing Record 30 of Set 14 | sovetskiy
# Processing Record 31 of Set 14 | tawnat
# City not found. Skipping...
# Processing Record 32 of Set 14 | coihaique
# Processing Record 33 of Set 14 | sibolga
# Processing Record 34 of Set 14 | hokitika
# Processing Record 35 of Set 14 | guerrero negro
# Processing Record 36 of Set 14 | camopi
# Processing Record 37 of Set 14 | somotillo
# Processing Record 38 of Set 14 | logan
# Processing Record 39 of Set 14 | poltavka
# Processing Record 40 of Set 14 | ola
# Processing Record 41 of Set 14 | manicore
# Processing Record 42 of Set 14 | belmonte
# Processing Record 43 of Set 14 | singarayakonda
# Processing Record 44 of Set 14 | mantua
# Processing Record 45 of Set 14 | nuevo progreso
# Processing Record 46 of Set 14 | olinda
# Processing Record 47 of Set 14 | port lincoln
# Processing Record 48 of Set 14 | san carlos de bariloche
# Processing Record 49 of Set 14 | shelburne
# Processing Record 50 of Set 14 | blonduos
# City not found. Skipping...
# Processing Record 1 of Set 15 | buala
# Processing Record 2 of Set 15 | lavumisa
# Processing Record 3 of Set 15 | smithers
# Processing Record 4 of Set 15 | tabuk
# Processing Record 5 of Set 15 | mahon
# Processing Record 6 of Set 15 | kirakira
# Processing Record 7 of Set 15 | manokwari
# Processing Record 8 of Set 15 | miles city
# Processing Record 9 of Set 15 | boyabat
# Processing Record 10 of Set 15 | pavilosta
# Processing Record 11 of Set 15 | port keats
# Processing Record 12 of Set 15 | ventspils
# Processing Record 13 of Set 15 | tuy hoa
# Processing Record 14 of Set 15 | dunedin
# Processing Record 15 of Set 15 | acapulco
# Processing Record 16 of Set 15 | jalor
# Processing Record 17 of Set 15 | belgrade
# Processing Record 18 of Set 15 | saint-georges
# Processing Record 19 of Set 15 | mahibadhoo
# Processing Record 20 of Set 15 | sanmenxia
# Processing Record 21 of Set 15 | dakar
# Processing Record 22 of Set 15 | torit
# Processing Record 23 of Set 15 | daru
# Processing Record 24 of Set 15 | callaway
# Processing Record 25 of Set 15 | bandipur
# Processing Record 26 of Set 15 | minuri
# Processing Record 27 of Set 15 | falealupo
# City not found. Skipping...
# Processing Record 28 of Set 15 | deputatskiy
# Processing Record 29 of Set 15 | slave lake
# Processing Record 30 of Set 15 | colomiers
# Processing Record 31 of Set 15 | rodrigues alves
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 671

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Jiuquan      CN  39.7432   98.5174     62.83        30          83
# 1   Tuktoyaktuk      CA  69.4541 -133.0374     36.55        66         100
# 2     Killybegs      IE  54.6333   -8.4500     59.45        83          87
# 3      Thompson      CA  55.7435  -97.8558     47.79        56          97
# 4    Kaitangata      NZ -46.2817  169.8464     38.50        91          15
# 5  San Patricio      US  28.0170  -97.5169     95.02        43           0
# 6    Georgetown      MY   5.4112  100.3354     80.89        88          98
# 7      Saldanha      ZA -33.0117   17.9442     56.88        74           0
# 8        Torbay      CA  47.6666  -52.7314     63.88        54          67
# 9      Cherskiy      RU  68.7500  161.3000     26.01        73          88
#
#    Wind Speed Current Description
# 0        0.51       broken clouds
# 1       18.50     overcast clouds
# 2       17.02     overcast clouds
# 3        2.28     overcast clouds
# 4        7.09          light rain
# 5        6.33           clear sky
# 6        6.44     overcast clouds
# 7       14.00           clear sky
# 8       10.83       broken clouds
# 9        4.12     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
